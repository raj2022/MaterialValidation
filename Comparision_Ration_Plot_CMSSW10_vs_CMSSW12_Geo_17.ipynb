# %% [markdown]
# Ratio plot with different outputs. We have seven different outputs from the fraction radiation length ($x/X_0$) vs Pseudorapidity($\eta$). We tried to figure out how the output from different CMSSW affect on the material validation outputs. This comparison is only for **Geometry2017Plan1**.

# %%
import numpy as np
import ROOT 
import uproot  # We have not used it but there could be another way to oen a root file, https://uproot.readthedocs.io/en/latest/basic.html 
import os       
import matplotlib.pyplot as plt 
# %matplotlib  #https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html 
# %matplotlib widget
from ROOT import TFile, TCanvas, TPad, TPaveLabel, TPaveText, TTree, TH1F, TF1
# from root_numpy import root2array, tree2array, array2tree, array2root
import sys
from ROOT import gROOT, AddressOf
from ROOT import TColor
from ROOT import kBlack, kBlue, kRed, kViolet
from ROOT import TCanvas, TColor, TGaxis, TH1F, TPad

# from root_numpy import root2array, rec2array

# %%
ROOT.gROOT.SetBatch()
ROOT.gStyle.SetOptStat(0)

# %% [markdown]
# #  Files
# Reading the root file with the outputs from CMSSW_12 and CMSSW_10 with geometry 2017.

# %%
# Importing file with CMSSW 12 output for geometry2017Plan1
infile_12 = ROOT.TFile ("/afs/cern.ch/user/s/sraj/GeometryTask/CMSSW_12_4_14/src/Validation/Geometry/test/matbdg_Tracker_Extended2017Plan1.root "," READ ")
infile_12.ls();
# Out:
# TFile**		/afs/cern.ch/user/s/sraj/GeometryTask/CMSSW_12_4_14/src/Validation/Geometry/test/matbdg_Tracker_Extended2017Plan1.root
#  TFile*		/afs/cern.ch/user/s/sraj/GeometryTask/CMSSW_12_4_14/src/Validation/Geometry/test/matbdg_Tracker_Extended2017Plan1.root
#   KEY: TH1F	11;1	Eta
#   KEY: TH1F	21;1	Phi
#   KEY: TH1F	41;1	R
#   KEY: TH1F	111;1	Eta [Support]
#   KEY: TH1F	121;1	Phi [Support]
#   KEY: TH1F	141;1	R [Support]
#   KEY: TH1F	211;1	Eta [Sensitive]
#   KEY: TH1F	221;1	Phi [Sensitive]
#   KEY: TH1F	241;1	R [Sensitive]
#   KEY: TH1F	311;1	Eta [Cables]
#   KEY: TH1F	321;1	Phi [Cables]
#   KEY: TH1F	341;1	R [Cables]
#   KEY: TH1F	411;1	Eta [Cooling]
#   KEY: TH1F	421;1	Phi [Cooling]
#   KEY: TH1F	441;1	R [Cooling]
#   KEY: TH1F	511;1	Eta [Electronics]
#   KEY: TH1F	521;1	Phi [Electronics]
#   KEY: TH1F	541;1	R [Electronics]
#   KEY: TH1F	611;1	Eta [Other]
#   KEY: TH1F	621;1	Phi [Other]
#   KEY: TH1F	641;1	R [Other]
#   KEY: TH1F	711;1	Eta [Air]
#   KEY: TH1F	721;1	Phi [Air]
#   KEY: TH1F	741;1	R [Air]
#   KEY: TH1F	1011;1	Eta
#   KEY: TH1F	1021;1	Phi
#   KEY: TH1F	1041;1	R
#   KEY: TH1F	1111;1	Eta [Support]
#   KEY: TH1F	1121;1	Phi [Support]
#   KEY: TH1F	1141;1	R [Support]
#   KEY: TH1F	1211;1	Eta [Sensitive]
#   KEY: TH1F	1221;1	Phi [Sensitive]
#   KEY: TH1F	1241;1	R [Sensitive]
#   KEY: TH1F	1311;1	Eta [Cables]
#   KEY: TH1F	1321;1	Phi [Cables]
#   KEY: TH1F	1341;1	R [Cables]
#   KEY: TH1F	1411;1	Eta [Cooling]
#   KEY: TH1F	1421;1	Phi [Cooling]
#   KEY: TH1F	1441;1	R [Cooling]
#   KEY: TH1F	1511;1	Eta [Electronics]
#   KEY: TH1F	1521;1	Phi [Electronics]
#   KEY: TH1F	1541;1	R [Electronics]
#   KEY: TH1F	1611;1	Eta [Other]
#   KEY: TH1F	1621;1	Phi [Other]
#   KEY: TH1F	1641;1	R [Other]
#   KEY: TH1F	1711;1	Eta [Air]
#   KEY: TH1F	1721;1	Phi [Air]
#   KEY: TH1F	1741;1	R [Air]
#   KEY: TH2F	31;1	Eta vs Phi
#   KEY: TH2F	51;1	R vs z
#   KEY: TH2F	60;1	MB prof local R  z
#   KEY: TH2F	61;1	R vs z
#   KEY: TH2F	131;1	Eta vs Phi [Support]
#   KEY: TH2F	151;1	R vs z [Support]
#   KEY: TH2F	160;1	MB prof local R  z [Support]
#   KEY: TH2F	161;1	R vs z [Support]
#   KEY: TH2F	231;1	Eta vs Phi [Sensitive]
#   KEY: TH2F	251;1	R vs z [Sensitive]
#   KEY: TH2F	260;1	MB prof local R  z [Sensitive]
#   KEY: TH2F	261;1	R vs z [Sensitive]
#   KEY: TH2F	331;1	Eta vs Phi [Cables]
#   KEY: TH2F	351;1	R vs z [Cables]
#   KEY: TH2F	360;1	MB prof local R  z [Cables]
#   KEY: TH2F	361;1	R vs z [Cables]
#   KEY: TH2F	431;1	Eta vs Phi [Cooling]
#   KEY: TH2F	451;1	R vs z [Cooling]
#   KEY: TH2F	460;1	MB prof local R  z [Cooling]
#   KEY: TH2F	461;1	R vs z [Cooling]
#   KEY: TH2F	531;1	Eta vs Phi [Electronics]
#   KEY: TH2F	551;1	R vs z [Electronics]
#   KEY: TH2F	560;1	MB prof local R  z [Electronics]
#   KEY: TH2F	561;1	R vs z [Electronics]
#   KEY: TH2F	631;1	Eta vs Phi [Other]
#   KEY: TH2F	651;1	R vs z [Other]
#   KEY: TH2F	660;1	MB prof local R  z [Other]
#   KEY: TH2F	661;1	R vs z [Other]
#   KEY: TH2F	731;1	Eta vs Phi [Air]
#   KEY: TH2F	751;1	R vs z [Air]
#   KEY: TH2F	760;1	MB prof local R  z [Air]
#   KEY: TH2F	761;1	R vs z [Air]
#   KEY: TH2F	999;1	Tot track length for MB
#   KEY: TH2F	1031;1	Eta vs Phi
#   KEY: TH2F	1051;1	R vs z
#   KEY: TH2F	1060;1	MB prof local R  z
#   KEY: TH2F	1061;1	R vs z
#   KEY: TH2F	1131;1	Eta vs Phi [Support]
#   KEY: TH2F	1151;1	R vs z [Support]
#   KEY: TH2F	1160;1	MB prof local R  z [Support]
#   KEY: TH2F	1161;1	R vs z [Support]
#   KEY: TH2F	1231;1	Eta vs Phi [Sensitive]
#   KEY: TH2F	1251;1	R vs z [Sensitive]
#   KEY: TH2F	1260;1	MB prof local R  z [Sensitive]
#   KEY: TH2F	1261;1	R vs z [Sensitive]
#   KEY: TH2F	1331;1	Eta vs Phi [Cables]
#   KEY: TH2F	1351;1	R vs z [Cables]
#   KEY: TH2F	1360;1	MB prof local R  z [Cables]
#   KEY: TH2F	1361;1	R vs z [Cables]
#   KEY: TH2F	1431;1	Eta vs Phi [Cooling]
#   KEY: TH2F	1451;1	R vs z [Cooling]
#   KEY: TH2F	1460;1	MB prof local R  z [Cooling]
#   KEY: TH2F	1461;1	R vs z [Cooling]
#   KEY: TH2F	1531;1	Eta vs Phi [Electronics]
#   KEY: TH2F	1551;1	R vs z [Electronics]
#   KEY: TH2F	1560;1	MB prof local R  z [Electronics]
#   KEY: TH2F	1561;1	R vs z [Electronics]
#   KEY: TH2F	1631;1	Eta vs Phi [Other]
#   KEY: TH2F	1651;1	R vs z [Other]
#   KEY: TH2F	1660;1	MB prof local R  z [Other]
#   KEY: TH2F	1661;1	R vs z [Other]
#   KEY: TH2F	1731;1	Eta vs Phi [Air]
#   KEY: TH2F	1751;1	R vs z [Air]
#   KEY: TH2F	1760;1	MB prof local R  z [Air]
#   KEY: TH2F	1761;1	R vs z [Air]
#   KEY: TH2F	1999;1	Tot track length for l0
#   KEY: TProfile	10;1	MB prof Eta [Total]
#   KEY: TProfile	20;1	MB prof Phi [Total]
#   KEY: TProfile	40;1	MB prof R [Total]
#   KEY: TProfile	110;1	MB prof Eta [Support]
#   KEY: TProfile	120;1	MB prof Phi [Support]
#   KEY: TProfile	140;1	MB prof R [Support]
#   KEY: TProfile	210;1	MB prof Eta [Sensitive]
#   KEY: TProfile	220;1	MB prof Phi [Sensitive]
#   KEY: TProfile	240;1	MB prof R [Sensitive]
#   KEY: TProfile	310;1	MB prof Eta [Cables]
#   KEY: TProfile	320;1	MB prof Phi [Cables]
#   KEY: TProfile	340;1	MB prof R [Cables]
#   KEY: TProfile	410;1	MB prof Eta [Cooling]
#   KEY: TProfile	420;1	MB prof Phi [Cooling]
#   KEY: TProfile	440;1	MB prof R [Cooling]
#   KEY: TProfile	510;1	MB prof Eta [Electronics]
#   KEY: TProfile	520;1	MB prof Phi [Electronics]
#   KEY: TProfile	540;1	MB prof R [Electronics]
#   KEY: TProfile	610;1	MB prof Eta [Other]
#   KEY: TProfile	620;1	MB prof Phi [Other]
#   KEY: TProfile	640;1	MB prof R [Other]
#   KEY: TProfile	710;1	MB prof Eta [Air]
#   KEY: TProfile	720;1	MB prof Phi [Air]
#   KEY: TProfile	740;1	MB prof R [Air]
#   KEY: TProfile	1010;1	MB prof Eta [Total]
#   KEY: TProfile	1020;1	MB prof Phi [Total]
#   KEY: TProfile	1040;1	MB prof R [Total]
#   KEY: TProfile	1110;1	MB prof Eta [Support]
#   KEY: TProfile	1120;1	MB prof Phi [Support]
#   KEY: TProfile	1140;1	MB prof R [Support]
#   KEY: TProfile	1210;1	MB prof Eta [Sensitive]
#   KEY: TProfile	1220;1	MB prof Phi [Sensitive]
#   KEY: TProfile	1240;1	MB prof R [Sensitive]
#   KEY: TProfile	1310;1	MB prof Eta [Cables]
#   KEY: TProfile	1320;1	MB prof Phi [Cables]
#   KEY: TProfile	1340;1	MB prof R [Cables]
#   KEY: TProfile	1410;1	MB prof Eta [Cooling]
#   KEY: TProfile	1420;1	MB prof Phi [Cooling]
#   KEY: TProfile	1440;1	MB prof R [Cooling]
#   KEY: TProfile	1510;1	MB prof Eta [Electronics]
#   KEY: TProfile	1520;1	MB prof Phi [Electronics]
#   KEY: TProfile	1540;1	MB prof R [Electronics]
#   KEY: TProfile	1610;1	MB prof Eta [Other]
#   KEY: TProfile	1620;1	MB prof Phi [Other]
#   KEY: TProfile	1640;1	MB prof R [Other]
#   KEY: TProfile	1710;1	MB prof Eta [Air]
#   KEY: TProfile	1720;1	MB prof Phi [Air]
#   KEY: TProfile	1740;1	MB prof R [Air]
#   KEY: TProfile2D	30;1	MB prof Eta  Phi [Total]
#   KEY: TProfile2D	50;1	MB prof sum R  z [Total]
#   KEY: TProfile2D	130;1	MB prof Eta  Phi [Support]
#   KEY: TProfile2D	150;1	MB prof sum R  z [Support]
#   KEY: TProfile2D	230;1	MB prof Eta  Phi [Sensitive]
#   KEY: TProfile2D	250;1	MB prof sum R  z [Sensitive]
#   KEY: TProfile2D	330;1	MB prof Eta  Phi [Cables]
#   KEY: TProfile2D	350;1	MB prof sum R  z [Cables]
#   KEY: TProfile2D	430;1	MB prof Eta  Phi [Cooling]
#   KEY: TProfile2D	450;1	MB prof sum R  z [Cooling]
#   KEY: TProfile2D	530;1	MB prof Eta  Phi [Electronics]
#   KEY: TProfile2D	550;1	MB prof sum R  z [Electronics]
#   KEY: TProfile2D	630;1	MB prof Eta  Phi [Other]
#   KEY: TProfile2D	650;1	MB prof sum R  z [Other]
#   KEY: TProfile2D	730;1	MB prof Eta  Phi [Air]
#   KEY: TProfile2D	750;1	MB prof sum R  z [Air]
#   KEY: TProfile2D	1030;1	MB prof Eta  Phi [Total]
#   KEY: TProfile2D	1050;1	MB prof sum R  z [Total]
#   KEY: TProfile2D	1130;1	MB prof Eta  Phi [Support]
#   KEY: TProfile2D	1150;1	MB prof sum R  z [Support]
#   KEY: TProfile2D	1230;1	MB prof Eta  Phi [Sensitive]
#   KEY: TProfile2D	1250;1	MB prof sum R  z [Sensitive]
#   KEY: TProfile2D	1330;1	MB prof Eta  Phi [Cables]
#   KEY: TProfile2D	1350;1	MB prof sum R  z [Cables]
#   KEY: TProfile2D	1430;1	MB prof Eta  Phi [Cooling]
#   KEY: TProfile2D	1450;1	MB prof sum R  z [Cooling]
#   KEY: TProfile2D	1530;1	MB prof Eta  Phi [Electronics]
#   KEY: TProfile2D	1550;1	MB prof sum R  z [Electronics]
#   KEY: TProfile2D	1630;1	MB prof Eta  Phi [Other]
#   KEY: TProfile2D	1650;1	MB prof sum R  z [Other]
#   KEY: TProfile2D	1730;1	MB prof Eta  Phi [Air]
#   KEY: TProfile2D	1750;1	MB prof sum R  z [Air]

# %%
# Importing file with CMSSW 12 output for geometry2017Plan1
infile_10 = ROOT.TFile("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Images_10_3_5_geom2017/matbdg_Tracker_Extended2017Plan1.root")
infile_10.ls();
# Out:
# TFile**		/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Images_10_3_5_geom2017/matbdg_Tracker_Extended2017Plan1.root
#  TFile*		/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Images_10_3_5_geom2017/matbdg_Tracker_Extended2017Plan1.root
#   KEY: TH1F	11;1	Eta
#   KEY: TH1F	21;1	Phi
#   KEY: TH1F	41;1	R
#   KEY: TH1F	111;1	Eta [Support]
#   KEY: TH1F	121;1	Phi [Support]
#   KEY: TH1F	141;1	R [Support]
#   KEY: TH1F	211;1	Eta [Sensitive]
#   KEY: TH1F	221;1	Phi [Sensitive]
#   KEY: TH1F	241;1	R [Sensitive]
#   KEY: TH1F	311;1	Eta [Cables]
#   KEY: TH1F	321;1	Phi [Cables]
#   KEY: TH1F	341;1	R [Cables]
#   KEY: TH1F	411;1	Eta [Cooling]
#   KEY: TH1F	421;1	Phi [Cooling]
#   KEY: TH1F	441;1	R [Cooling]
#   KEY: TH1F	511;1	Eta [Electronics]
#   KEY: TH1F	521;1	Phi [Electronics]
#   KEY: TH1F	541;1	R [Electronics]
#   KEY: TH1F	611;1	Eta [Other]
#   KEY: TH1F	621;1	Phi [Other]
#   KEY: TH1F	641;1	R [Other]
#   KEY: TH1F	711;1	Eta [Air]
#   KEY: TH1F	721;1	Phi [Air]
#   KEY: TH1F	741;1	R [Air]
#   KEY: TH1F	1011;1	Eta
#   KEY: TH1F	1021;1	Phi
#   KEY: TH1F	1041;1	R
#   KEY: TH1F	1111;1	Eta [Support]
#   KEY: TH1F	1121;1	Phi [Support]
#   KEY: TH1F	1141;1	R [Support]
#   KEY: TH1F	1211;1	Eta [Sensitive]
#   KEY: TH1F	1221;1	Phi [Sensitive]
#   KEY: TH1F	1241;1	R [Sensitive]
#   KEY: TH1F	1311;1	Eta [Cables]
#   KEY: TH1F	1321;1	Phi [Cables]
#   KEY: TH1F	1341;1	R [Cables]
#   KEY: TH1F	1411;1	Eta [Cooling]
#   KEY: TH1F	1421;1	Phi [Cooling]
#   KEY: TH1F	1441;1	R [Cooling]
#   KEY: TH1F	1511;1	Eta [Electronics]
#   KEY: TH1F	1521;1	Phi [Electronics]
#   KEY: TH1F	1541;1	R [Electronics]
#   KEY: TH1F	1611;1	Eta [Other]
#   KEY: TH1F	1621;1	Phi [Other]
#   KEY: TH1F	1641;1	R [Other]
#   KEY: TH1F	1711;1	Eta [Air]
#   KEY: TH1F	1721;1	Phi [Air]
#   KEY: TH1F	1741;1	R [Air]
#   KEY: TH2F	31;1	Eta vs Phi
#   KEY: TH2F	51;1	R vs z
#   KEY: TH2F	60;1	MB prof local R  z
#   KEY: TH2F	61;1	R vs z
#   KEY: TH2F	131;1	Eta vs Phi [Support]
#   KEY: TH2F	151;1	R vs z [Support]
#   KEY: TH2F	160;1	MB prof local R  z [Support]
#   KEY: TH2F	161;1	R vs z [Support]
#   KEY: TH2F	231;1	Eta vs Phi [Sensitive]
#   KEY: TH2F	251;1	R vs z [Sensitive]
#   KEY: TH2F	260;1	MB prof local R  z [Sensitive]
#   KEY: TH2F	261;1	R vs z [Sensitive]
#   KEY: TH2F	331;1	Eta vs Phi [Cables]
#   KEY: TH2F	351;1	R vs z [Cables]
#   KEY: TH2F	360;1	MB prof local R  z [Cables]
#   KEY: TH2F	361;1	R vs z [Cables]
#   KEY: TH2F	431;1	Eta vs Phi [Cooling]
#   KEY: TH2F	451;1	R vs z [Cooling]
#   KEY: TH2F	460;1	MB prof local R  z [Cooling]
#   KEY: TH2F	461;1	R vs z [Cooling]
#   KEY: TH2F	531;1	Eta vs Phi [Electronics]
#   KEY: TH2F	551;1	R vs z [Electronics]
#   KEY: TH2F	560;1	MB prof local R  z [Electronics]
#   KEY: TH2F	561;1	R vs z [Electronics]
#   KEY: TH2F	631;1	Eta vs Phi [Other]
#   KEY: TH2F	651;1	R vs z [Other]
#   KEY: TH2F	660;1	MB prof local R  z [Other]
#   KEY: TH2F	661;1	R vs z [Other]
#   KEY: TH2F	731;1	Eta vs Phi [Air]
#   KEY: TH2F	751;1	R vs z [Air]
#   KEY: TH2F	760;1	MB prof local R  z [Air]
#   KEY: TH2F	761;1	R vs z [Air]
#   KEY: TH2F	999;1	Tot track length for MB
#   KEY: TH2F	1031;1	Eta vs Phi
#   KEY: TH2F	1051;1	R vs z
#   KEY: TH2F	1060;1	MB prof local R  z
#   KEY: TH2F	1061;1	R vs z
#   KEY: TH2F	1131;1	Eta vs Phi [Support]
#   KEY: TH2F	1151;1	R vs z [Support]
#   KEY: TH2F	1160;1	MB prof local R  z [Support]
#   KEY: TH2F	1161;1	R vs z [Support]
#   KEY: TH2F	1231;1	Eta vs Phi [Sensitive]
#   KEY: TH2F	1251;1	R vs z [Sensitive]
#   KEY: TH2F	1260;1	MB prof local R  z [Sensitive]
#   KEY: TH2F	1261;1	R vs z [Sensitive]
#   KEY: TH2F	1331;1	Eta vs Phi [Cables]
#   KEY: TH2F	1351;1	R vs z [Cables]
#   KEY: TH2F	1360;1	MB prof local R  z [Cables]
#   KEY: TH2F	1361;1	R vs z [Cables]
#   KEY: TH2F	1431;1	Eta vs Phi [Cooling]
#   KEY: TH2F	1451;1	R vs z [Cooling]
#   KEY: TH2F	1460;1	MB prof local R  z [Cooling]
#   KEY: TH2F	1461;1	R vs z [Cooling]
#   KEY: TH2F	1531;1	Eta vs Phi [Electronics]
#   KEY: TH2F	1551;1	R vs z [Electronics]
#   KEY: TH2F	1560;1	MB prof local R  z [Electronics]
#   KEY: TH2F	1561;1	R vs z [Electronics]
#   KEY: TH2F	1631;1	Eta vs Phi [Other]
#   KEY: TH2F	1651;1	R vs z [Other]
#   KEY: TH2F	1660;1	MB prof local R  z [Other]
#   KEY: TH2F	1661;1	R vs z [Other]
#   KEY: TH2F	1731;1	Eta vs Phi [Air]
#   KEY: TH2F	1751;1	R vs z [Air]
#   KEY: TH2F	1760;1	MB prof local R  z [Air]
#   KEY: TH2F	1761;1	R vs z [Air]
#   KEY: TH2F	1999;1	Tot track length for l0
#   KEY: TProfile	10;1	MB prof Eta [Total]
#   KEY: TProfile	20;1	MB prof Phi [Total]
#   KEY: TProfile	40;1	MB prof R [Total]
#   KEY: TProfile	110;1	MB prof Eta [Support]
#   KEY: TProfile	120;1	MB prof Phi [Support]
#   KEY: TProfile	140;1	MB prof R [Support]
#   KEY: TProfile	210;1	MB prof Eta [Sensitive]
#   KEY: TProfile	220;1	MB prof Phi [Sensitive]
#   KEY: TProfile	240;1	MB prof R [Sensitive]
#   KEY: TProfile	310;1	MB prof Eta [Cables]
#   KEY: TProfile	320;1	MB prof Phi [Cables]
#   KEY: TProfile	340;1	MB prof R [Cables]
#   KEY: TProfile	410;1	MB prof Eta [Cooling]
#   KEY: TProfile	420;1	MB prof Phi [Cooling]
#   KEY: TProfile	440;1	MB prof R [Cooling]
#   KEY: TProfile	510;1	MB prof Eta [Electronics]
#   KEY: TProfile	520;1	MB prof Phi [Electronics]
#   KEY: TProfile	540;1	MB prof R [Electronics]
#   KEY: TProfile	610;1	MB prof Eta [Other]
#   KEY: TProfile	620;1	MB prof Phi [Other]
#   KEY: TProfile	640;1	MB prof R [Other]
#   KEY: TProfile	710;1	MB prof Eta [Air]
#   KEY: TProfile	720;1	MB prof Phi [Air]
#   KEY: TProfile	740;1	MB prof R [Air]
#   KEY: TProfile	1010;1	MB prof Eta [Total]
#   KEY: TProfile	1020;1	MB prof Phi [Total]
#   KEY: TProfile	1040;1	MB prof R [Total]
#   KEY: TProfile	1110;1	MB prof Eta [Support]
#   KEY: TProfile	1120;1	MB prof Phi [Support]
#   KEY: TProfile	1140;1	MB prof R [Support]
#   KEY: TProfile	1210;1	MB prof Eta [Sensitive]
#   KEY: TProfile	1220;1	MB prof Phi [Sensitive]
#   KEY: TProfile	1240;1	MB prof R [Sensitive]
#   KEY: TProfile	1310;1	MB prof Eta [Cables]
#   KEY: TProfile	1320;1	MB prof Phi [Cables]
#   KEY: TProfile	1340;1	MB prof R [Cables]
#   KEY: TProfile	1410;1	MB prof Eta [Cooling]
#   KEY: TProfile	1420;1	MB prof Phi [Cooling]
#   KEY: TProfile	1440;1	MB prof R [Cooling]
#   KEY: TProfile	1510;1	MB prof Eta [Electronics]
#   KEY: TProfile	1520;1	MB prof Phi [Electronics]
#   KEY: TProfile	1540;1	MB prof R [Electronics]
#   KEY: TProfile	1610;1	MB prof Eta [Other]
#   KEY: TProfile	1620;1	MB prof Phi [Other]
#   KEY: TProfile	1640;1	MB prof R [Other]
#   KEY: TProfile	1710;1	MB prof Eta [Air]
#   KEY: TProfile	1720;1	MB prof Phi [Air]
#   KEY: TProfile	1740;1	MB prof R [Air]
#   KEY: TProfile2D	30;1	MB prof Eta  Phi [Total]
#   KEY: TProfile2D	50;1	MB prof sum R  z [Total]
#   KEY: TProfile2D	130;1	MB prof Eta  Phi [Support]
#   KEY: TProfile2D	150;1	MB prof sum R  z [Support]
#   KEY: TProfile2D	230;1	MB prof Eta  Phi [Sensitive]
#   KEY: TProfile2D	250;1	MB prof sum R  z [Sensitive]
#   KEY: TProfile2D	330;1	MB prof Eta  Phi [Cables]
#   KEY: TProfile2D	350;1	MB prof sum R  z [Cables]
#   KEY: TProfile2D	430;1	MB prof Eta  Phi [Cooling]
#   KEY: TProfile2D	450;1	MB prof sum R  z [Cooling]
#   KEY: TProfile2D	530;1	MB prof Eta  Phi [Electronics]
#   KEY: TProfile2D	550;1	MB prof sum R  z [Electronics]
#   KEY: TProfile2D	630;1	MB prof Eta  Phi [Other]
#   KEY: TProfile2D	650;1	MB prof sum R  z [Other]
#   KEY: TProfile2D	730;1	MB prof Eta  Phi [Air]
#   KEY: TProfile2D	750;1	MB prof sum R  z [Air]
#   KEY: TProfile2D	1030;1	MB prof Eta  Phi [Total]
#   KEY: TProfile2D	1050;1	MB prof sum R  z [Total]
#   KEY: TProfile2D	1130;1	MB prof Eta  Phi [Support]
#   KEY: TProfile2D	1150;1	MB prof sum R  z [Support]
#   KEY: TProfile2D	1230;1	MB prof Eta  Phi [Sensitive]
#   KEY: TProfile2D	1250;1	MB prof sum R  z [Sensitive]
#   KEY: TProfile2D	1330;1	MB prof Eta  Phi [Cables]
#   KEY: TProfile2D	1350;1	MB prof sum R  z [Cables]
#   KEY: TProfile2D	1430;1	MB prof Eta  Phi [Cooling]
#   KEY: TProfile2D	1450;1	MB prof sum R  z [Cooling]
#   KEY: TProfile2D	1530;1	MB prof Eta  Phi [Electronics]
#   KEY: TProfile2D	1550;1	MB prof sum R  z [Electronics]
#   KEY: TProfile2D	1630;1	MB prof Eta  Phi [Other]
#   KEY: TProfile2D	1650;1	MB prof sum R  z [Other]
#   KEY: TProfile2D	1730;1	MB prof Eta  Phi [Air]
#   KEY: TProfile2D	1750;1	MB prof sum R  z [Air]

# %% [markdown]
# # 1. Ratio Plots for Cooling

# %%
hist_12_cooling = infile_12.Get("410") #"410" is the file name inside the root file
hist_10_cooling = infile_10.Get("410") 

#Define the file which can count as the datafile.
hist_12_cooling.SetMarkerStyle(20)
hist_12_cooling.SetMarkerSize(1) 
hist_12_cooling.SetMarkerColor(kBlack)
hist_12_cooling.SetLineWidth(1)
hist_12_cooling.SetLineColor(kViolet)
# hist_12_cooling.GetYaxis().SetRangeUser(0.001,1)       # No need 


#Define the total MC with adding all of the histograms
totalMC= ROOT.TH1F("totalMC", "Events;DNN score;",-5,5,250)
totalMC.Add(hist_10_cooling)
totalMCYield=totalMC.Integral()
DataYield= hist_12_cooling.Integral()
DataMC_scaleF=DataYield/totalMCYield  

# SCaling the file and defining the histogram
hist_10_cooling.Scale(DataMC_scaleF)
hist_10_cooling.SetFillColor(7)
hist_10_cooling.SetLineColor(kBlue);
# hist_10_cooling.GetYaxis().SetRangeUser(0.001, 1)

# Defining the Stack of the histogram
stack_I = ROOT.THStack("","")
stack_I.Add(hist_10_cooling)


# Define the hRatio plot
hRatio = hist_12_cooling.Clone("hRatio");
hRatio.Reset();
hRatio.Add(hist_12_cooling);
hRatio.Divide(hist_10_cooling);
hRatio.SetStats(0);
hRatio.SetMarkerStyle(20);
hRatio.SetMarkerSize(1);
hRatio.SetTitle("");


hRatio.GetYaxis().SetRangeUser(0.1,2.7);
hRatio.GetYaxis().SetTitleOffset(0.4);
hRatio.GetYaxis().SetTitleSize(0.13);
hRatio.GetXaxis().SetTitleSize(0.12);
hRatio.GetXaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetTitle("#frac{CMSSW_12}{CMSSW_10}");
hRatio.GetXaxis().SetTitle("eta($\eta$)");
hRatio.GetXaxis().SetLabelOffset(0.035);
hRatio.GetYaxis().SetLabelOffset(0.01);
hRatio.GetYaxis().SetNdivisions(5);
hRatio.SetMarkerStyle(19);
hRatio.SetMarkerSize(0.5);
hRatio.SetMarkerColor(kBlack);
# hRatio.Fit("pol1")   #It shows the fit 

# Definging the Canvas

c1 = ROOT.TCanvas('c1',"",1000,1200)
pad1 = ROOT.TPad("pad1","pad1",0,0.3,1.0,1.0);
pad1.SetTopMargin(0.090);
pad1.SetBottomMargin(0);
pad1.SetLeftMargin(0.120);
pad1.SetRightMargin(0.070);
pad1.SetLogy();
pad1.SetTickx();
pad1.SetTicky();
pad1.Draw();
pad1.cd();

# Defining the text "CMS Premilinary"
tex1 = ROOT.TLatex(0.12, 0.94, "#bf{CMS} #it{Premilinary}")
tex1.SetNDC()
tex1.SetTextAlign(13)
tex1.SetTextFont(42)
tex1.SetTextSize(0.03)
tex1.SetLineWidth(2)

#NO need of this but anyway we do not need to draw it
tex2 = ROOT.TLatex(0.72, 0.94, "137 fb^{-1} (13 TeV)")
tex2.SetNDC()
tex2.SetTextAlign(13)
tex2.SetTextFont(42)
tex2.SetTextSize(0.03)
tex2.SetLineWidth(2)

# Drawing the histogram
stack_I.Draw("hist")
stack_I.GetYaxis().SetTitle("X/X_0");
# stack_I.GetYaxis().SetRangeUser(0.001, 1)
stack_I.SetMaximum(0.8) #Setting the maximum of the upper pad , we can similary define the minimum for the lower pad.

#Drawing the histogram on the same pad.
hist_12_cooling.Draw("E0 x0 SAME")
 
# Legend drawing
legend = ROOT.TLegend()
legend = ROOT.TLegend(0.40,0.80,0.80,0.89)
legend.AddEntry(hist_12_cooling, "Cooling-CMSSW_12X")
legend.AddEntry(hist_10_cooling, "Cooling-CMSSW_10X")

# canvas.SetLogy()
legend.Draw()
# canvas.Draw()

#Text Drawing
tex1.Draw()


#Defing the pad 2 with the ratio plot
pad2 = TPad("pad2","pad2",0,0,1,0.3);
pad2.SetTopMargin(0.1);
pad2.SetLeftMargin(0.120);
pad2.SetRightMargin(0.070);
pad2.SetBottomMargin(0.35);
pad2.SetGridy();
pad2.SetGridx();
pad2.Draw();
pad2.cd();

hRatio.Draw("E0 x0");
# Draw
c1.Draw()
# Saving the file 
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Cooling_comaprision_CMSSW_10&12.pdf")
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Cooling_comaprision_CMSSW_10&12.png")
# Out:
# Warning in <TH1::TH1>: nbins is <=0 - set to nbins = 1
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %% [markdown]
# # 2. Ratio Plot for Cables

# %%
hist_12_cooling = infile_12.Get("310")
hist_10_cooling = infile_10.Get("310")


hist_12_cooling.SetMarkerStyle(20)
hist_12_cooling.SetMarkerSize(1)
hist_12_cooling.SetMarkerColor(kBlack)
hist_12_cooling.SetLineWidth(1)
hist_12_cooling.SetLineColor(kViolet)
# hist_12_cooling.GetYaxis().SetRangeUser(0.001,1)


totalMC= ROOT.TH1F("totalMC", "Events;DNN score;",-5,5,250)
totalMC.Add(hist_10_cooling)
totalMCYield=totalMC.Integral()
DataYield= hist_12_cooling.Integral()
DataMC_scaleF=DataYield/totalMCYield  


hist_10_cooling.Scale(DataMC_scaleF)

hist_10_cooling.SetFillColor(7)
hist_10_cooling.SetLineColor(kBlue);
hist_10_cooling.GetYaxis().SetRangeUser(0.001, 1)

stack_I = ROOT.THStack("","")
stack_I.Add(hist_10_cooling)



hRatio = hist_12_cooling.Clone("hRatio");
hRatio.Reset();
hRatio.Add(hist_12_cooling);
hRatio.Divide(hist_10_cooling);
hRatio.SetStats(0);
hRatio.SetMarkerStyle(20);
hRatio.SetMarkerSize(1);
hRatio.SetTitle("");


hRatio.GetYaxis().SetRangeUser(0.1,2.7);
hRatio.GetYaxis().SetTitleOffset(0.4);
hRatio.GetYaxis().SetTitleSize(0.13);
hRatio.GetXaxis().SetTitleSize(0.12);
hRatio.GetXaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetTitle("#frac{CMSSW_12}{CMSSW_10}");
hRatio.GetXaxis().SetTitle("eta($\eta$)");
hRatio.GetXaxis().SetLabelOffset(0.035);
hRatio.GetYaxis().SetLabelOffset(0.01);
hRatio.GetYaxis().SetNdivisions(5);
hRatio.SetMarkerStyle(19);
hRatio.SetMarkerSize(0.5);
hRatio.SetMarkerColor(kBlack);
# hRatio.Fit("pol1")   #It shows the fit 

c1 = ROOT.TCanvas('c1',"",1000,1200)
pad1 = ROOT.TPad("pad1","pad1",0,0.3,1.0,1.0);
pad1.SetTopMargin(0.090);
pad1.SetBottomMargin(0);
pad1.SetLeftMargin(0.120);
pad1.SetRightMargin(0.070);
pad1.SetLogy();
pad1.SetTickx();
pad1.SetTicky();
pad1.Draw();
pad1.cd();

tex1 = ROOT.TLatex(0.12, 0.94, "#bf{CMS} #it{Premilinary}")
tex1.SetNDC()
tex1.SetTextAlign(13)
tex1.SetTextFont(42)
tex1.SetTextSize(0.03)
tex1.SetLineWidth(2)

tex2 = ROOT.TLatex(0.72, 0.94, "137 fb^{-1} (13 TeV)")
tex2.SetNDC()
tex2.SetTextAlign(13)
tex2.SetTextFont(42)
tex2.SetTextSize(0.03)
tex2.SetLineWidth(2)

stack_I.Draw("hist")
stack_I.GetYaxis().SetTitle("X/X_0");
# stack_I.GetYaxis().SetRangeUser(0.001, 1)
stack_I.SetMaximum(1.0)


hist_12_cooling.Draw("E0 x0 SAME")

# Legend drawing
legend = ROOT.TLegend()
legend = ROOT.TLegend(0.35,0.82,0.73,0.90)
legend.AddEntry(hist_12_cooling, "Cables-CMSSW_12X")
legend.AddEntry(hist_10_cooling, "Cables-CMSSW_10X")

# canvas.SetLogy()
legend.Draw()
# canvas.Draw()

tex1.Draw()



pad2 = TPad("pad2","pad2",0,0,1,0.3);
pad2.SetTopMargin(0.1);
pad2.SetLeftMargin(0.120);
pad2.SetRightMargin(0.070);
pad2.SetBottomMargin(0.35);
pad2.SetGridy();
pad2.SetGridx();
pad2.Draw();
pad2.cd();

hRatio.Draw("E0 x0");
c1.Draw()
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Cables_comaprision_CMSSW_10&12.pdf")
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Cables_comaprision_CMSSW_10&12.png")
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: totalMC (Potential memory leak).
# Warning in <TH1::TH1>: nbins is <=0 - set to nbins = 1
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: pdf file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Cables_comaprision_CMSSW_10&12.pdf has been created
# Info in <TCanvas::Print>: png file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Cables_comaprision_CMSSW_10&12.png has been created

# %% [markdown]
# # Ratio Plot for Electronics

# %%
hist_12_cooling = infile_12.Get("510")
hist_10_cooling = infile_10.Get("510")


hist_12_cooling.SetMarkerStyle(20)
hist_12_cooling.SetMarkerSize(1)
hist_12_cooling.SetMarkerColor(kBlack)
hist_12_cooling.SetLineWidth(1)
hist_12_cooling.SetLineColor(kViolet)
# hist_12_cooling.GetYaxis().SetRangeUser(0.001,1)


totalMC= ROOT.TH1F("totalMC", "Events;DNN score;",-5,5,250)
totalMC.Add(hist_10_cooling)
totalMCYield=totalMC.Integral()
DataYield= hist_12_cooling.Integral()
DataMC_scaleF=DataYield/totalMCYield  


hist_10_cooling.Scale(DataMC_scaleF)

hist_10_cooling.SetFillColor(7)
hist_10_cooling.SetLineColor(kBlue);
# hist_10_cooling.GetYaxis().SetRangeUser(0.001, 1)

stack_I = ROOT.THStack("","")
stack_I.Add(hist_10_cooling)



hRatio = hist_12_cooling.Clone("hRatio");
hRatio.Reset();
hRatio.Add(hist_12_cooling);
hRatio.Divide(hist_10_cooling);
hRatio.SetStats(0);
hRatio.SetMarkerStyle(20);
hRatio.SetMarkerSize(1);
hRatio.SetTitle("");


hRatio.GetYaxis().SetRangeUser(0.1,3.2);
hRatio.GetYaxis().SetTitleOffset(0.4);
hRatio.GetYaxis().SetTitleSize(0.13);
hRatio.GetXaxis().SetTitleSize(0.12);
hRatio.GetXaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetTitle("#frac{CMSSW_12}{CMSSW_10}");
hRatio.GetXaxis().SetTitle("eta($\eta$)");
hRatio.GetXaxis().SetLabelOffset(0.035);
hRatio.GetYaxis().SetLabelOffset(0.01);
hRatio.GetYaxis().SetNdivisions(5);
hRatio.SetMarkerStyle(19);
hRatio.SetMarkerSize(0.5);
hRatio.SetMarkerColor(kBlack);
# hRatio.Fit("pol1")   #It shows the fit 

c1 = ROOT.TCanvas('c1',"",1000,1200)
pad1 = ROOT.TPad("pad1","pad1",0,0.3,1.0,1.0);
pad1.SetTopMargin(0.090);
pad1.SetBottomMargin(0);
pad1.SetLeftMargin(0.120);
pad1.SetRightMargin(0.070);
pad1.SetLogy();
pad1.SetTickx();
pad1.SetTicky();
pad1.Draw();
pad1.cd();

tex1 = ROOT.TLatex(0.12, 0.94, "#bf{CMS} #it{Premilinary}")
tex1.SetNDC()
tex1.SetTextAlign(13)
tex1.SetTextFont(42)
tex1.SetTextSize(0.03)
tex1.SetLineWidth(2)

tex2 = ROOT.TLatex(0.72, 0.94, "137 fb^{-1} (13 TeV)")
tex2.SetNDC()
tex2.SetTextAlign(13)
tex2.SetTextFont(42)
tex2.SetTextSize(0.03)
tex2.SetLineWidth(2)

stack_I.Draw("hist")
stack_I.GetYaxis().SetTitle("X/X_0");
# stack_I.GetYaxis().SetRangeUser(0.001, 1)
stack_I.SetMaximum(1.0)


hist_12_cooling.Draw("E0 x0 SAME")

# Legend drawing
legend = ROOT.TLegend()
legend = ROOT.TLegend(0.35,0.825,0.75,0.89)
legend.AddEntry(hist_12_cooling, "Electronics-CMSSW_12X")
legend.AddEntry(hist_10_cooling, "Electronics-CMSSW_10X")

# canvas.SetLogy()
legend.Draw()
# canvas.Draw()

tex1.Draw()



pad2 = TPad("pad2","pad2",0,0,1,0.3);
pad2.SetTopMargin(0.1);
pad2.SetLeftMargin(0.120);
pad2.SetRightMargin(0.070);
pad2.SetBottomMargin(0.35);
pad2.SetGridy();
pad2.SetGridx();
pad2.Draw();
pad2.cd();

hRatio.Draw("E0 x0");
c1.Draw()
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Electronics_comaprision_CMSSW_10&12.pdf")
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Electronics_comaprision_CMSSW_10&12.png")
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: totalMC (Potential memory leak).
# Warning in <TH1::TH1>: nbins is <=0 - set to nbins = 1
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: pdf file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Electronics_comaprision_CMSSW_10&12.pdf has been created
# Info in <TCanvas::Print>: png file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Electronics_comaprision_CMSSW_10&12.png has been created

# %% [markdown]
# # Ratio Plot for Others

# %%
hist_12_cooling = infile_12.Get("610")
hist_10_cooling = infile_10.Get("610")


hist_12_cooling.SetMarkerStyle(20)
hist_12_cooling.SetMarkerSize(1)
hist_12_cooling.SetMarkerColor(kBlack)
hist_12_cooling.SetLineWidth(1)
hist_12_cooling.SetLineColor(kViolet)
# hist_12_cooling.GetYaxis().SetRangeUser(0.001,1)


totalMC= ROOT.TH1F("totalMC", "Events;DNN score;",-5,5,250)
totalMC.Add(hist_10_cooling)
totalMCYield=totalMC.Integral()
DataYield= hist_12_cooling.Integral()
DataMC_scaleF=DataYield/totalMCYield  


hist_10_cooling.Scale(DataMC_scaleF)

hist_10_cooling.SetFillColor(7)
hist_10_cooling.SetLineColor(kBlue);
hist_10_cooling.GetYaxis().SetRangeUser(0.001, 0.1)

stack_I = ROOT.THStack("","")
stack_I.Add(hist_10_cooling)



hRatio = hist_12_cooling.Clone("hRatio");
hRatio.Reset();
hRatio.Add(hist_12_cooling);
hRatio.Divide(hist_10_cooling);
hRatio.SetStats(0);
hRatio.SetMarkerStyle(20);
hRatio.SetMarkerSize(1);
hRatio.SetTitle("");


hRatio.GetYaxis().SetRangeUser(0.1,3);
hRatio.GetYaxis().SetTitleOffset(0.4);
hRatio.GetYaxis().SetTitleSize(0.13);
hRatio.GetXaxis().SetTitleSize(0.12);
hRatio.GetXaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetTitle("#frac{CMSSW_12}{CMSSW_10}");
hRatio.GetXaxis().SetTitle("eta($\eta$)");
hRatio.GetXaxis().SetLabelOffset(0.035);
hRatio.GetYaxis().SetLabelOffset(0.01);
hRatio.GetYaxis().SetNdivisions(5);
hRatio.SetMarkerStyle(19);
hRatio.SetMarkerSize(0.5);
hRatio.SetMarkerColor(kBlack);
# hRatio.Fit("pol1")   #It shows the fit 

c1 = ROOT.TCanvas('c1',"",1000,1200)
pad1 = ROOT.TPad("pad1","pad1",0,0.3,1.0,1.0);
pad1.SetTopMargin(0.090);
pad1.SetBottomMargin(0);
pad1.SetLeftMargin(0.120);
pad1.SetRightMargin(0.070);
pad1.SetLogy();
pad1.SetTickx();
pad1.SetTicky();
pad1.Draw();
pad1.cd();

tex1 = ROOT.TLatex(0.12, 0.94, "#bf{CMS} #it{Premilinary}")
tex1.SetNDC()
tex1.SetTextAlign(13)
tex1.SetTextFont(42)
tex1.SetTextSize(0.03)
tex1.SetLineWidth(2)

tex2 = ROOT.TLatex(0.72, 0.94, "137 fb^{-1} (13 TeV)")
tex2.SetNDC()
tex2.SetTextAlign(13)
tex2.SetTextFont(42)
tex2.SetTextSize(0.03)
tex2.SetLineWidth(2)

stack_I.Draw("hist")
stack_I.GetYaxis().SetTitle("X/X_0");
# stack_I.GetYaxis().SetRangeUser(0.001, 1)
stack_I.SetMaximum(0.5)
stack_I.SetMinimum(0.00001)

hist_12_cooling.Draw("E0 x0 SAME")

# Legend drawing
legend = ROOT.TLegend()
legend = ROOT.TLegend(0.38,0.81,0.80,0.89)
legend.AddEntry(hist_12_cooling, "Others-CMSSW_12X")
legend.AddEntry(hist_10_cooling, "Others-CMSSW_10X")

# canvas.SetLogy()
legend.Draw()
# canvas.Draw()

tex1.Draw()



pad2 = TPad("pad2","pad2",0,0,1,0.3);
pad2.SetTopMargin(0.1);
pad2.SetLeftMargin(0.120);
pad2.SetRightMargin(0.070);
pad2.SetBottomMargin(0.35);
pad2.SetGridy();
pad2.SetGridx();
pad2.Draw();
pad2.cd();

hRatio.Draw("E0 x0");
c1.Draw()
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Other_comaprision_CMSSW_10&12.pdf")
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Other_comaprision_CMSSW_10&12.png")
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: totalMC (Potential memory leak).
# Warning in <TH1::TH1>: nbins is <=0 - set to nbins = 1
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: pdf file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Other_comaprision_CMSSW_10&12.pdf has been created
# Info in <TCanvas::Print>: png file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Other_comaprision_CMSSW_10&12.png has been created

# %% [markdown]
# # Ratio Plot for Air

# %%
hist_12_cooling = infile_12.Get("710")
hist_10_cooling = infile_10.Get("710")


hist_12_cooling.SetMarkerStyle(20)
hist_12_cooling.SetMarkerSize(1)
hist_12_cooling.SetMarkerColor(kBlack)
hist_12_cooling.SetLineWidth(1)
hist_12_cooling.SetLineColor(kViolet)
# hist_12_cooling.GetYaxis().SetRangeUser(0.001,1)


totalMC= ROOT.TH1F("totalMC", "Events;DNN score;",-5,5,250)
totalMC.Add(hist_10_cooling)
totalMCYield=totalMC.Integral()
DataYield= hist_12_cooling.Integral()
DataMC_scaleF=DataYield/totalMCYield  


hist_10_cooling.Scale(DataMC_scaleF)

hist_10_cooling.SetFillColor(7)
hist_10_cooling.SetLineColor(kBlue);
# hist_10_cooling.GetYaxis().SetRangeUser(0.001, 1)

stack_I = ROOT.THStack("","")
stack_I.Add(hist_10_cooling)



hRatio = hist_12_cooling.Clone("hRatio");
hRatio.Reset();
hRatio.Add(hist_12_cooling);
hRatio.Divide(hist_10_cooling);
hRatio.SetStats(0);
hRatio.SetMarkerStyle(20);
hRatio.SetMarkerSize(1);
hRatio.SetTitle("");


hRatio.GetYaxis().SetRangeUser(0.1,2.7);
hRatio.GetYaxis().SetTitleOffset(0.4);
hRatio.GetYaxis().SetTitleSize(0.13);
hRatio.GetXaxis().SetTitleSize(0.12);
hRatio.GetXaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetTitle("#frac{CMSSW_12}{CMSSW_10}");
hRatio.GetXaxis().SetTitle("eta($\eta$)");
hRatio.GetXaxis().SetLabelOffset(0.035);
hRatio.GetYaxis().SetLabelOffset(0.01);
hRatio.GetYaxis().SetNdivisions(5);
hRatio.SetMarkerStyle(19);
hRatio.SetMarkerSize(0.5);
hRatio.SetMarkerColor(kBlack);
# hRatio.Fit("pol1")   #It shows the fit 

c1 = ROOT.TCanvas('c1',"",1000,1200)
pad1 = ROOT.TPad("pad1","pad1",0,0.3,1.0,1.0);
pad1.SetTopMargin(0.090);
pad1.SetBottomMargin(0);
pad1.SetLeftMargin(0.120);
pad1.SetRightMargin(0.070);
pad1.SetLogy();
pad1.SetTickx();
pad1.SetTicky();
pad1.Draw();
pad1.cd();

tex1 = ROOT.TLatex(0.12, 0.94, "#bf{CMS} #it{Premilinary}")
tex1.SetNDC()
tex1.SetTextAlign(13)
tex1.SetTextFont(42)
tex1.SetTextSize(0.03)
tex1.SetLineWidth(2)

tex2 = ROOT.TLatex(0.72, 0.94, "137 fb^{-1} (13 TeV)")
tex2.SetNDC()
tex2.SetTextAlign(13)
tex2.SetTextFont(42)
tex2.SetTextSize(0.03)
tex2.SetLineWidth(2)

stack_I.Draw("hist")
stack_I.GetYaxis().SetTitle("X/X_0");
# stack_I.GetYaxis().SetRangeUser(0.001, 1)
stack_I.SetMaximum(0.02)
stack_I.SetMinimum(0.00001)

hist_12_cooling.Draw("E0 x0 SAME")

# Legend drawing
legend = ROOT.TLegend()
legend = ROOT.TLegend(0.38,0.82,0.80,0.90)
legend.AddEntry(hist_12_cooling, "Air-CMSSW_12X")
legend.AddEntry(hist_10_cooling, "Air-CMSSW_10X")

# canvas.SetLogy()
legend.Draw()
# canvas.Draw()

tex1.Draw()



pad2 = TPad("pad2","pad2",0,0,1,0.3);
pad2.SetTopMargin(0.1);
pad2.SetLeftMargin(0.120);
pad2.SetRightMargin(0.070);
pad2.SetBottomMargin(0.35);
pad2.SetGridy();
pad2.SetGridx();
pad2.Draw();
pad2.cd();

hRatio.Draw("E0 x0");
c1.Draw()
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Air_comaprision_CMSSW_10&12.pdf")
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Air_comaprision_CMSSW_10&12.png")
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: totalMC (Potential memory leak).
# Warning in <TH1::TH1>: nbins is <=0 - set to nbins = 1
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: pdf file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Air_comaprision_CMSSW_10&12.pdf has been created
# Info in <TCanvas::Print>: png file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Air_comaprision_CMSSW_10&12.png has been created

# %% [markdown]
# # Ratio plot for Sensitive

# %%
hist_12_cooling = infile_12.Get("210")
hist_10_cooling = infile_10.Get("210")


hist_12_cooling.SetMarkerStyle(20)
hist_12_cooling.SetMarkerSize(1)
hist_12_cooling.SetMarkerColor(kBlack)
hist_12_cooling.SetLineWidth(1)
hist_12_cooling.SetLineColor(kViolet)
# hist_12_cooling.GetYaxis().SetRangeUser(0.001,1)


totalMC= ROOT.TH1F("totalMC", "Events;DNN score;",-5,5,250)
totalMC.Add(hist_10_cooling)
totalMCYield=totalMC.Integral()
DataYield= hist_12_cooling.Integral()
DataMC_scaleF=DataYield/totalMCYield  


hist_10_cooling.Scale(DataMC_scaleF)

hist_10_cooling.SetFillColor(7)
hist_10_cooling.SetLineColor(kBlue);
# hist_10_cooling.GetYaxis().SetRangeUser(0.001, 1)

stack_I = ROOT.THStack("","")
stack_I.Add(hist_10_cooling)



hRatio = hist_12_cooling.Clone("hRatio");
hRatio.Reset();
hRatio.Add(hist_12_cooling);
hRatio.Divide(hist_10_cooling);
hRatio.SetStats(0);
hRatio.SetMarkerStyle(20);
hRatio.SetMarkerSize(1);
hRatio.SetTitle("");


hRatio.GetYaxis().SetRangeUser(0.1,2.7);
hRatio.GetYaxis().SetTitleOffset(0.4);
hRatio.GetYaxis().SetTitleSize(0.13);
hRatio.GetXaxis().SetTitleSize(0.12);
hRatio.GetXaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetTitle("#frac{CMSSW_12}{CMSSW_10}");
hRatio.GetXaxis().SetTitle("eta($\eta$)");
hRatio.GetXaxis().SetLabelOffset(0.035);
hRatio.GetYaxis().SetLabelOffset(0.01);
hRatio.GetYaxis().SetNdivisions(5);
hRatio.SetMarkerStyle(19);
hRatio.SetMarkerSize(0.5);
hRatio.SetMarkerColor(kBlack);
# hRatio.Fit("pol1")   #It shows the fit 

c1 = ROOT.TCanvas('c1',"",1000,1200)
pad1 = ROOT.TPad("pad1","pad1",0,0.3,1.0,1.0);
pad1.SetTopMargin(0.090);
pad1.SetBottomMargin(0);
pad1.SetLeftMargin(0.120);
pad1.SetRightMargin(0.070);
pad1.SetLogy();
pad1.SetTickx();
pad1.SetTicky();
pad1.Draw();
pad1.cd();

tex1 = ROOT.TLatex(0.12, 0.94, "#bf{CMS} #it{Premilinary}")
tex1.SetNDC()
tex1.SetTextAlign(13)
tex1.SetTextFont(42)
tex1.SetTextSize(0.03)
tex1.SetLineWidth(2)

tex2 = ROOT.TLatex(0.72, 0.94, "137 fb^{-1} (13 TeV)")
tex2.SetNDC()
tex2.SetTextAlign(13)
tex2.SetTextFont(42)
tex2.SetTextSize(0.03)
tex2.SetLineWidth(2)

stack_I.Draw("hist")
stack_I.GetYaxis().SetTitle("X/X_0");
# stack_I.GetYaxis().SetRangeUser(0.001, 1)
stack_I.SetMaximum(0.2)
stack_I.SetMinimum(0.001)

hist_12_cooling.Draw("E0 x0 SAME")

# Legend drawing
legend = ROOT.TLegend()
legend = ROOT.TLegend(0.40,0.83,0.80,0.90)
legend.AddEntry(hist_12_cooling, "Sensitive-CMSSW_12X")
legend.AddEntry(hist_10_cooling, "Sensitive-CMSSW_10X")

# canvas.SetLogy()
legend.Draw()
# canvas.Draw()

tex1.Draw()



pad2 = TPad("pad2","pad2",0,0,1,0.3);
pad2.SetTopMargin(0.1);
pad2.SetLeftMargin(0.120);
pad2.SetRightMargin(0.070);
pad2.SetBottomMargin(0.35);
pad2.SetGridy();
pad2.SetGridx();
pad2.Draw();
pad2.cd();

hRatio.Draw("E0 x0");
c1.Draw()
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Sensitive_comaprision_CMSSW_10&12.pdf")
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Sensitive_comaprision_CMSSW_10&12.png")
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: totalMC (Potential memory leak).
# Warning in <TH1::TH1>: nbins is <=0 - set to nbins = 1
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: pdf file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Sensitive_comaprision_CMSSW_10&12.pdf has been created
# Info in <TCanvas::Print>: png file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Sensitive_comaprision_CMSSW_10&12.png has been created

# %% [markdown]
# # Ratio Plot for Support

# %%
hist_12_cooling = infile_12.Get("110")
hist_10_cooling = infile_10.Get("110")


hist_12_cooling.SetMarkerStyle(20)
hist_12_cooling.SetMarkerSize(1)
hist_12_cooling.SetMarkerColor(kBlack)
hist_12_cooling.SetLineWidth(1)
hist_12_cooling.SetLineColor(kViolet)
# hist_12_cooling.GetYaxis().SetRangeUser(0.001,1)


totalMC= ROOT.TH1F("totalMC", "Events;DNN score;",-5,5,250)
totalMC.Add(hist_10_cooling)
totalMCYield=totalMC.Integral()
DataYield= hist_12_cooling.Integral()
DataMC_scaleF=DataYield/totalMCYield  


hist_10_cooling.Scale(DataMC_scaleF)

hist_10_cooling.SetFillColor(7)
hist_10_cooling.SetLineColor(kBlue);
# hist_10_cooling.GetYaxis().SetRangeUser(0.001, 1)

stack_I = ROOT.THStack("","")
stack_I.Add(hist_10_cooling)



hRatio = hist_12_cooling.Clone("hRatio");
hRatio.Reset();
hRatio.Add(hist_12_cooling);
hRatio.Divide(hist_10_cooling);
hRatio.SetStats(0);
hRatio.SetMarkerStyle(20);
hRatio.SetMarkerSize(1);
hRatio.SetTitle("");


hRatio.GetYaxis().SetRangeUser(0.1,2.7);
hRatio.GetYaxis().SetTitleOffset(0.4);
hRatio.GetYaxis().SetTitleSize(0.13);
hRatio.GetXaxis().SetTitleSize(0.12);
hRatio.GetXaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetLabelSize(0.10);
hRatio.GetYaxis().SetTitle("#frac{CMSSW_12}{CMSSW_10}");
hRatio.GetXaxis().SetTitle("eta($\eta$)");
hRatio.GetXaxis().SetLabelOffset(0.035);
hRatio.GetYaxis().SetLabelOffset(0.01);
hRatio.GetYaxis().SetNdivisions(5);
hRatio.SetMarkerStyle(19);
hRatio.SetMarkerSize(0.5);
hRatio.SetMarkerColor(kBlack);
# hRatio.Fit("pol1")   #It shows the fit 

c1 = ROOT.TCanvas('c1',"",1000,1200)
pad1 = ROOT.TPad("pad1","pad1",0,0.3,1.0,1.0);
pad1.SetTopMargin(0.090);
pad1.SetBottomMargin(0);
pad1.SetLeftMargin(0.120);
pad1.SetRightMargin(0.070);
pad1.SetLogy();
pad1.SetTickx();
pad1.SetTicky();
pad1.Draw();
pad1.cd();

tex1 = ROOT.TLatex(0.12, 0.94, "#bf{CMS} #it{Premilinary}")
tex1.SetNDC()
tex1.SetTextAlign(13)
tex1.SetTextFont(42)
tex1.SetTextSize(0.03)
tex1.SetLineWidth(2)

tex2 = ROOT.TLatex(0.72, 0.94, "137 fb^{-1} (13 TeV)")
tex2.SetNDC()
tex2.SetTextAlign(13)
tex2.SetTextFont(42)
tex2.SetTextSize(0.03)
tex2.SetLineWidth(2)

stack_I.Draw("hist")
stack_I.GetYaxis().SetTitle("X/X_0");
# stack_I.GetYaxis().SetRangeUser(0.001, 1)
stack_I.SetMaximum(1.0)


hist_12_cooling.Draw("E0 x0 SAME")

# Legend drawing
legend = ROOT.TLegend()
legend = ROOT.TLegend(0.40,0.84,0.80,0.90)
legend.AddEntry(hist_12_cooling, "Support-CMSSW_12X")
legend.AddEntry(hist_10_cooling, "Support-CMSSW_10X")

# canvas.SetLogy()
legend.Draw()
# canvas.Draw()

tex1.Draw()



pad2 = TPad("pad2","pad2",0,0,1,0.3);
pad2.SetTopMargin(0.1);
pad2.SetLeftMargin(0.120);
pad2.SetRightMargin(0.070);
pad2.SetBottomMargin(0.35);
pad2.SetGridy();
pad2.SetGridx();
pad2.Draw();
pad2.cd();

hRatio.Draw("E0 x0");
c1.Draw()
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Support_comaprision_CMSSW_10&12.pdf")
c1.SaveAs("/eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Support_comaprision_CMSSW_10&12.png")
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: totalMC (Potential memory leak).
# Warning in <TH1::TH1>: nbins is <=0 - set to nbins = 1
# Info in <TH1F::Add>: Attempt to add histograms with different number of bins - trying to use TH1::Merge
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: pdf file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Support_comaprision_CMSSW_10&12.pdf has been created
# Info in <TCanvas::Print>: png file /eos/user/s/sraj/Work_/CUA_20--/Project_Material_Validation_V1/Comparision_CMSSW-10_&_CMSSW-12/Support_comaprision_CMSSW_10&12.png has been created
